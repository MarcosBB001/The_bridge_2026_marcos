# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![ejercicios.png](attachment:ejercicios.png)

# %% [markdown]
# ## PRACTICA OBLIGATORIA: COLECCIONES Y FUNCIONES

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste varios ejercicios de programación libre a completar sobre Colecciones y Funciones. Descarga este notebook en tu ordenador y trabaja en local.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente y puedas participar en dicha sesión.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### Contenidos

# %% [markdown]
# ## Ejercicio 1
# Eleva todos los elementos de la lista al cuadrado
# > ```ejer_2 = [1,2,3,4,5]```

# %%
ejer_2 = [1, 2, 3, 4, 5]

for i, e in enumerate(ejer_2):
    ejer_2[i] = ejer_2[i] ** 2

print(ejer_2)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ## Ejercicio 2
# Haz un programa que detecte todos los duplicados de un elemento en una lista:
# * Utiliza una variable duplicado para asignarle el valor del elemento del que queremos encontrar todos sus duplicados.
# * El programa debe devolver todos los índices de los elementos duplicados.
# * Aplícalo para encontrar los duplicados de "un", "es" y "binario" de:
#
# >```ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]```

# %%
ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]

elementos_duplicados = ["un", "es", "binario"]
dupli_indexes = []
for dupli in elementos_duplicados:
    dupli_counter = 0
    for i, e in enumerate(ejer_3):
        if e.lower() == dupli:  # Ambiguo si "Un" y "un" se consideran duplicados, asumo que si
            dupli_counter += 1
            if dupli_counter >= 2:
                dupli_indexes.append(i)

print("Indices elementos duplicados ", dupli_indexes)
# Out:
# Indices elementos duplicados  [7, 13, 15]

# %% [markdown]
# ## Ejercicio 3
# 1. ¿Cuántas veces se repite el 3 en la siguiente tupla?
# 2. Crea una tupla nueva con los elementos desde la posicion 5 a la 10.
# 3. ¿Cuántos elementos tiene la tupla `ejer_3`?
# > ```ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)```

# %%
ejer_3 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)

counts3 = ejer_3.count(3)
print("Numero 3 repetido: ", counts3)

nueva_tupla = ejer_3[5:11]
print(nueva_tupla)
print(type(nueva_tupla))

print("La tupla tiene el siguiente numero de elementos: ", len(ejer_3))
# Out:
# Numero 3 repetido:  7
# (3, 29, 45, 67, 78, 90)
# <class 'tuple'>
# La tupla tiene el siguiente numero de elementos:  26

# %% [markdown]
# ## Ejercicio 4
# Comprueba si el numero 60 esta en la tupla del ejercicio 3

# %%
if 60 in ejer_3:
    print("El numero 60 existe en la tupla")
else:
    print("El numero 60 no existe en la tupla")
# Out:
# El numero 60 no existe en la tupla

# %% [markdown]
# ## Ejercicio 5
# 1. Convierte la tupla del ejercicio 3 en una lista
# 2. Convierte la tupla del ejercicio 3 en un set
# 3. Convierte la tupla del ejercicio 3 en un diccionario. Usa también los indices

# %%
ejer_3_lista = list(ejer_3)
print("Lista: ", ejer_3_lista)

ejer_3_set = set(ejer_3)
print("Set: ", ejer_3_set)

ejer_3_dict = {}
for i, e in enumerate(ejer_3):
    ejer_3_dict[i] = e
    
print("Dictionary: ", ejer_3_dict)
# Out:
# Lista:  [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7]
# Set:  {2, 3, 67, 5, 4, 7, 6, 9, 45, 78, 47, 19, 20, 90, 29}
# Dictionary:  {0: 3, 1: 20, 2: 3, 3: 47, 4: 19, 5: 3, 6: 29, 7: 45, 8: 67, 9: 78, 10: 90, 11: 3, 12: 3, 13: 5, 14: 2, 15: 4, 16: 7, 17: 9, 18: 4, 19: 2, 20: 4, 21: 3, 22: 3, 23: 4, 24: 6, 25: 7}

# %% [markdown]
# ## Ejercicio 6
# Multiplica todos los valores del diccionario
# > ```ejer_6 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_6 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}

resultado = 1  # Elemento neitro de la multiplicacion
for v in ejer_6.values():
    resultado = resultado * v

print(resultado)
# Out:
# 19326120

# %% [markdown]
# ## Ejercicio 7
#
# 1. Crea un diccionario que describa un libro, con los siguientes campos o claves: "titulo","autor","idioma original","año de publicación".
# 2. Crea un a lista, llamada librería.
# 3. Añade cuatro libros a tu elección a la librería.

# %%
dict_libro = {"titulo": None, "autor": None, "idioma original": None, "ano de publicacion": None}

def crear_dict_libro(titulo, autor, idioma_orig, ano_publi):
    dict_libro = {"titulo": titulo, "autor": autor, "idioma original": idioma_orig, "ano de publicacion": ano_publi}

    return dict_libro

libreria = []
libro1 = crear_dict_libro("Primera aventura", "Eduardo", "Ingles", 1999)
libro2 = crear_dict_libro("Segunda aventura", "Eduardo", "Ingles", 2003)
libro3 = crear_dict_libro("El impostor", "Amogus", "Castellano", 2020)
libro4 = crear_dict_libro("Tercera aventura", "Eduardo", "Ingles", 2008)

libreria.append(libro1)
libreria.append(libro2)
libreria.append(libro3)
libreria.append(libro4)

print(libreria)
# Out:
# [{'titulo': 'Primera aventura', 'autor': 'Eduardo', 'idioma original': 'Ingles', 'ano de publicacion': 1999}, {'titulo': 'Segunda aventura', 'autor': 'Eduardo', 'idioma original': 'Ingles', 'ano de publicacion': 2003}, {'titulo': 'El impostor', 'autor': 'Amogus', 'idioma original': 'Castellano', 'ano de publicacion': 2020}, {'titulo': 'Tercera aventura', 'autor': 'Eduardo', 'idioma original': 'Ingles', 'ano de publicacion': 2008}]

# %% [markdown]
# ## Ejercicio 8
# Modifica los valores del idioma de todos los libros del ejercicio anterior para que sea "esperanto"

# %%
for libro in libreria:
    libro["idioma original"] = "esperanto"

print(libreria)
# Out:
# [{'titulo': 'Primera aventura', 'autor': 'Eduardo', 'idioma original': 'esperanto', 'ano de publicacion': 1999}, {'titulo': 'Segunda aventura', 'autor': 'Eduardo', 'idioma original': 'esperanto', 'ano de publicacion': 2003}, {'titulo': 'El impostor', 'autor': 'Amogus', 'idioma original': 'esperanto', 'ano de publicacion': 2020}, {'titulo': 'Tercera aventura', 'autor': 'Eduardo', 'idioma original': 'esperanto', 'ano de publicacion': 2008}]

# %% [markdown]
# ## Ejercicio 9
# 1. Escribe un programa que dada una variable titulo busque los libros que hay en la librería con ese título. Si no se encuentra debe devolver el mensaje `Ese no lo tengo, ¿mola?`
# 2. Pruena que el programa con uno de tus libros y con otro que no contenga tu librería.

# %%
titulo = "Segunda aventura"
encontrado = False
for libro in libreria:
    if libro["titulo"] == titulo:
        encontrado = True

if encontrado:
    print("El libro existe!: ", titulo)
else:
    print("Ese no lo tengo, ¿mola?: ", titulo)


titulo = "El superimpostor"
encontrado = False
for libro in titulo:
    if titulo in libro:
        encontrado = True

if encontrado:
    print("El libro existe!: ", titulo)
else:
    print("Ese no lo tengo, ¿mola?: ", titulo)
# Out:
# El libro existe!:  Segunda aventura
# Ese no lo tengo, ¿mola?:  El superimpostor

# %% [markdown]
# ## Ejercicio 10
# Convierte el programa del ejercicio 2 en una función al que se le pase el valor a buscar como un argumento posicional

# %%
ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]

def buscar_valores(valores):
    dupli_indexes = []
    for dupli in valores:
        dupli_counter = 0
        for i, e in enumerate(ejer_3):
            if e.lower() == dupli:  # Ambiguo si "Un" y "un" se consideran duplicados, asumo que si
                dupli_counter += 1
                if dupli_counter >= 2:
                    dupli_indexes.append(i)
    
    return dupli_indexes

elementos_duplicados = ["un", "es", "binario"]
dupli_indexes = buscar_valores(elementos_duplicados)
print(dupli_indexes)
# Out:
# [7, 13, 15]

# %% [markdown]
# ## Ejercicio 11
# Convierte el programa del ejercicio 9 en una función al que se le pasen como argumentos la librería, posicional, y el título, argumento keyword con valor "ninguno", por defecto.

# %%
def buscar_libro(libreria, titulo="ninguno"):
    encontrado = False
    for libro in libreria:
        if libro["titulo"] == titulo:
            encontrado = True

    if encontrado:
        print("El libro existe!: ", titulo)
    else:
        print("Ese no lo tengo, ¿mola?: ", titulo)

titulo = "Primera aventura"
buscar_libro(libreria, titulo)
# Out:
# El libro existe!:  Primera aventura

# %% [markdown]
# ## Ejercicio 12
# Solicitar al usuario que ingrese su dirección email. Imprimir un mensaje indicando si la dirección es válida o no, valiéndose de una función para decidirlo. Una dirección se considerará válida si contiene el símbolo "@".

# %%
email = input("Introduce tu dirección de email: ")
if "@" in email:
    print("Direccion de correo valida")
else:
    print("Direccion de correo NO valida")
# Out:
# Direccion de correo valida

# %% [markdown]
# ## Ejercicio 13
# Escribe una función que compruebe si un DNI es válido, devolviendo `True` en caso afirmativo.
# En primer lugar, el DNI debe tener entre 7 y 8 dígitos numéricos.
# Para saber si la letra del DNI es correcta puedes utilizar el siguiente fragmento de código:
# >```Python
# >DNI= 55555555
# >palabra='TRWAGMYFPDXBNJZSQVHLCKE'
# >print('La letra del DNI es: ', palabra[DNI%23])
# >````

# %%
def comprobar_validez_dni(dni):
    validez = False
    palabra='TRWAGMYFPDXBNJZSQVHLCKE'
    n_digitos = 0
    n_letras = 0
    for letra in dni:
        try:
            int(letra)
            n_digitos += 1
        except:
            if letra in palabra:
                n_letras += 1

    if (n_digitos == 7 or n_digitos == 8) and (n_letras == 1):
        validez = True
    return validez

dni_valido = "12345678Z"
es_valido = comprobar_validez_dni(dni_valido)
print("¿Es valido el DNI?: ", es_valido)
# Out:
# ¿Es valido el DNI?:  True
